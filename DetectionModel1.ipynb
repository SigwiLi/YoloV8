# %%
# !unzip FIsh5V2.zip
# Out:
# Archive:  FIsh5V2.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/IMG_0297_jpg.rf.5243ea39b80d9705d38f1c23226d3cf5.jpg
#  extracting: test/images/IMG_0303_jpg.rf.68cf7023ea7b6ac76019dd978bda768f.jpg
#  extracting: test/images/IMG_0318_jpg.rf.a19b5586c10bce7870edc5757392ba4c.jpg
#    creating: test/labels/
#   inflating: test/labels/IMG_0297_jpg.rf.5243ea39b80d9705d38f1c23226d3cf5.txt
#   inflating: test/labels/IMG_0303_jpg.rf.68cf7023ea7b6ac76019dd978bda768f.txt
#   inflating: test/labels/IMG_0318_jpg.rf.a19b5586c10bce7870edc5757392ba4c.txt
#    creating: train/
#    creating: train/images/
#  extracting: train/images/IMG_0287_jpg.rf.eaad93a83459f02aa383114ac42686cc.jpg
#  extracting: train/images/IMG_0287_jpg.rf.ee16ea2b933eb668ecf8e25a75dafe86.jpg
#  extracting: train/images/IMG_0287_jpg.rf.f61bd3f5163ec0abc90d9d73267d7c06.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content
# Ultralytics 8.3.145 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
